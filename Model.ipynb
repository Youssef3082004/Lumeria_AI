# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
users = pd.read_csv("Datasets/Users.csv")
users
# Out:
#                                    user_id         username  place_id  \
# 0     04fab766-306b-4f35-a83e-4655f052392d         dina_ali         7
# 1     04fab766-306b-4f35-a83e-4655f052392d         dina_ali        71
# 2     04fab766-306b-4f35-a83e-4655f052392d         dina_ali        63
# 3     04fab766-306b-4f35-a83e-4655f052392d         dina_ali        58
# 4     04fab766-306b-4f35-a83e-4655f052392d         dina_ali        36
# ...                                    ...              ...       ...
# 1033  ff583213-7dba-47eb-9070-258374a87e64  Gamal Awadallah       149
# 1034  ff583213-7dba-47eb-9070-258374a87e64  Gamal Awadallah        15
# 1035  ff583213-7dba-47eb-9070-258374a87e64  Gamal Awadallah       139
# 1036  ff583213-7dba-47eb-9070-258374a87e64  Gamal Awadallah        24
# 1037  ff583213-7dba-47eb-9070-258374a87e64  Gamal Awadallah        67
#
#                           place_name  rating
# 0              Obelisk of Senusret I       3
# ...
